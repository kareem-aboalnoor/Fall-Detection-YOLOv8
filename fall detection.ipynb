# %%
# Test GPU And CUDA Availability
import torch

print("Torch version:", torch.__version__)
print("CUDA version:", torch.version.cuda)
print("CUDA available:", torch.cuda.is_available())
print("cuDNN version:", torch.backends.cudnn.version())
print("Number of CUDA devices:", torch.cuda.device_count())
print("Current CUDA device index:", torch.cuda.current_device())
if torch.cuda.is_available():
    print("Current CUDA device name:", torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# Torch version: 2.9.1+cu130
# CUDA version: 13.0
# CUDA available: True
# cuDNN version: 91200
# Number of CUDA devices: 1
# Current CUDA device index: 0
# Current CUDA device name: NVIDIA GeForce RTX 3050

# %%
#load and train model

from ultralytics import YOLO

model = YOLO("best.pt")

model.train(
    data='Fall Detection.v4-resized640_aug3x-accurate.yolov8\data.yaml',
    epochs=10,
    imgsz=640,
    batch=8,
    workers=5,
    project='Fall_detection',
    name='fall_recognition'
)
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\kareem aboalnoor\AppData\Local\Temp\ipykernel_4524\1243397221.py:8: SyntaxWarning: invalid escape sequence '\d'
#   data='Fall Detection.v4-resized640_aug3x-accurate.yolov8\data.yaml',
# New https://pypi.org/project/ultralytics/8.3.241 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.240  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 3050, 8192MiB)
# ...
